# %% [markdown]
# # The Perils of Data Journalism: Amateurism, Ambiguity, and the Pursuit of Contrarianism

# %% [markdown]
# #### [Brian Keegan, Ph.D.](www.brianckeegan.com) \([@bkeegan](https://twitter.com/bkeegan)\) College of Humanities and Social Sciences, Northeastern University

# %% [markdown]
# A spectre haunting is haunting the web --- the spectre of "data journalism." All of the powers of old Journalism have entered into holy evangelism to praise this paradigm: *Post* and *Times*, Silver and Klein, New York designers and Bay Area developers.
#
# Where I depart in this "manifesto" is to echo others' observations that "data journalism", having faced the world and published their analyses, has been found wanting. I have found three specific critiques, made in part by Krugman \[[1](http://krugman.blogs.nytimes.com/2014/03/18/sergeant-friday-was-not-a-fox/),[2](http://krugman.blogs.nytimes.com/2014/03/18/further-thoughts-on-hedgehogs-and-foxes/),[3](http://krugman.blogs.nytimes.com/2014/03/23/tarnished-silver/),[4](http://krugman.blogs.nytimes.com/2014/03/26/data-as-slogan-data-as-substance/)\] and Noah Smith \[[5](http://noahpinionblog.blogspot.com/2014/03/data-buzzword-vs-data-actual-thing.html)\] (and abetted by Silver's [petulant response to Krugman](http://fivethirtyeight.com/datalab/for-columnist-a-change-of-tone/) and Kieran Healy's [excellent analysis](http://kieranhealy.org/blog/archives/2014/03/26/silver-vs-krugman/) of the same), the most persuasive:
#
# 1. **Amateurism.** Data journalists' exploratory analyses often overlook scientists', analysts', and other experts' well-established methods and hard-won expertise. That the data and tools for analyzing them are increasingly available is stupendous gain for science and society --- but with great power comes great responsibility. Just because the conclusions of "experts" in political media are terrifyingly unreliable does not mean the conclusions of "experts" in economics, climate science, and other scientific fields are similarly disruptable by enterprising data munging. Rather than attempting to become data analysts themselves, data journalists should perform preliminary analyses and seek the advice of or collaborate directly with well-credentialed scientists and analysts to corroborate them.
#
# 2. **Ambiguity.** These analyses appear with the veneer of empirical rigor, clad in infographics crying out for Edward Tufte's approval and containing intimidating words like "Bayesian" or "regression". But they offer little substantive detail in terms of the sources of these data and even fewer specifics about the types of analyses used. In scientific research, these methodological details---while inevitably dense and boring---are the instruction manual for interpreting the validity the analysis and its findings; you can do far [more damage with a bad model](http://xkcd.com/605/) than with an improperly-assembled [IKEA Björnholmen storage unit](http://www.buzzfeed.com/saraboboltz/some-people-arent-very-good-at-ikea-af7c). It is essential that journalists make the data and models they use open for inspection. This not only aids other researchers who want to replicate or extend the finding, it also compels the author to revise their information (how Bayesian!) and learn about new approaches.
#
# 3. **Pursuit of contrarianism.** I am very much sympathetic to journalists whose professional fortunes are increasingly yoked to the capricious tyrants of pageviews, optimized headlines, and other behavioral nebulae. However, the thirst for clicks has corrupted journalists' skepticism and contributed to an increasingly toxic culture of contrarianism. Several FiveThirtyEight articles have bear-hugged the framing of "everything you know about X is wrong." If everything that is known also true? [No](http://i.imgur.com/j74SykU.gif). Should we use data analysis to test claims? [Yes](http://xkcd.com/552/). Can data be tortured into making false confessions? [Easily](https://archive.org/details/HowToLieWithStatistics). But journalists, with correlations in hand from the most easily-scraped database, are not heroes for standing athwart scientific consensus, yelling stop.
#
# In the remainder of this post, I explore these three themes by analyzing a recent FiveThirtyEight article on the relationship between financial performance of films and their representations of women. First, I will point out some glaring inconsistencies in the interpretation of the reported statistical findings taking the author at his word. Second, I will attempt to replicate the findings and, failing to do so because of the ambiguities in the methods described, explore alternative models. This second part forms the bulk of this document and becomes technical, but that's the "[Iron Price](http://gameofthrones.wikia.com/wiki/Iron_price)" one pays for making statistical inferences.
#
# By virtue of me writing this post and making it publicly available for review on GitHub, I am making accessible data that I scraped from websites that curate and make public several types of movie data. There are certainly other data resources out there. I am also inviting critiques both about my arguments and execution that have the potential to expose me to ridicule but I welcome as they will clarify my thinking and understanding of methods. I encourage others to do the same in sharing their data, documenting and posting their models, and attempting to speak to broader audiences. To that end, I've benefitted from feedback from XXX.
#
# Since parables are apparently the new (cryptic) currency in data journalism manifestos, let me conclude with this one about the [The Dancing Monkeys](http://www.aesopfables.com/cgi/aesop1.cgi?sel&TheDancingMonkeys):
#
# > A Prince had some Monkeys trained to dance.  Being naturally great mimics of men's actions, they showed themselves most apt pupils, and when arrayed in their rich clothes and masks, they danced as well as any of the courtiers.  The spectacle was often repeated with great applause, till on one occasion a courtier, bent on mischief, took from his pocket a handful of nuts and threw them upon the stage.  The Monkeys at the sight of the nuts forgot their dancing and became (as indeed they were) Monkeys instead of actors.  Pulling off their masks and tearing their robes, they fought with one another for the nuts.  The dancing spectacle thus came to an end amidst the laughter and ridicule of the audience.
#
# > "Not everything you see is what it appears to be."
#
# **The tl;dr is that women's representation in films not only has a significant, positive, and tiny effect on box office revenue but it also has a significant, negative, and moderate effect on popular and critical ratings. Also too, share your work or you risk being exposed as a dancing monkey.**

# %% [markdown]
# ### The Bechdel Test article in FiveThirtyEight

# %% [markdown]
# Walk Hickey published an article on April 1 on FiveThirtyEight, titled [The Dollar-And-Cents Case Against Hollywood’s Exclusion of Women](http://fivethirtyeight.com/features/the-dollar-and-cents-case-against-hollywoods-exclusion-of-women/). The article makes two central claims:
#
# > 1. We found that the median budget of movies that passed the test...was substantially lower than the median budget of all films in the sample.
#
# > 2. ...we found evidence that films that feature meaningful interactions between women may in fact have a better return on investment, overall, than films that don’t.
#
# I call Claim 1 the "Budgets Differ" finding and Claim 2 the "Earnings Differ" finding. The results, as they're summarized here are relatively straightforward to test: run a [One-way ANOVA](https://en.wikipedia.org/wiki/One-way_analysis_of_variance) to test the first and use a [multivariate regression model](https://en.wikipedia.org/wiki/Linear_regression) to estimate the effect of Bechdel score on earnings controlling for other explanatory variables to test the second.
#
# But before we even get to running the numbers, I want to examine the claims Hickey made in the article. The interpretations he makes about the return on investment are particularly problematic. Hickey reports the following findings from his models (emphasis added).
# > We did a statistical analysis of films to test two claims: first, that films that pass the Bechdel test — featuring women in stronger roles — see a lower return on investment, and second, that they see lower gross profits. We found no evidence to support either claim.
#
# > On the first test, we ran a regression to find out if passing the Bechdel test corresponded to lower return on investment. Controlling for the movie’s budget, which has a negative and significant relationship to a film’s return on investment, **passing the Bechdel test had no effect on the film’s return on investment.** In other words, adding women to a film’s cast didn’t hurt its investors’ returns, contrary to what Hollywood investors seem to believe.
#
# > The total median gross return on investment for a film that passed the Bechdel test was \$2.68 for each dollar spent. The total median gross return on investment for films that failed was only \$2.45 for each dollar spent.
#
# > ...On the second test, we ran a regression to find out if passing the Bechdel test corresponded to having lower gross profits — domestic and international. Also controlling for the movie’s budget, which has a positive and significant relationship to a film’s gross profits, once again **passing the Bechdel test did not have any effect on a film’s gross profits.**
#
# Both models (whatever their faults, and there are many as we will explore in the next section) apparently produce an estimate that the Bechdel test has no effect on a film's financial performance. That is to say, the statistical test could not determine with a greater than 95% confidence that the correlation between these two variables was greater or less than 0. *Because we cannot confidently rule out the possibility of there being zero effect, we cannot make any claims about its direction.*
#
# Hickey argues that passing the test "didn't hurt its investors' returns", which is to say there was no significant negative relationship, but neither was there a significant positive relationship: *The model provides no evidence of a positive correlation between Bechdel scores and financial performance.* However, Hickey switches gears an in the conclusions, writes:
#
# > ...our data demonstrates that films containing meaningful interactions between women **do better at the box office than movies that don’t**...
#
# I don't know what analysis supports this interpretation. The analysis Hickey just performed, again taking the finding at its face, concluded that "passing the Bechdel test did not have any effect on a film’s gross profits" ***not*** "passing the Bechdel test increased the film's profits." While Bayesians will cavail about frequentist assumptions --- as they are wont to do --- and the absence of evidence is not evidence of absence, the "Results Differ finding" is empirically supported in no appropriate interpretation of the analysis. The appropriate conclusion from Hickey's analysis is there no relationship between the Bechdel test and financial performance, which he makes then ignores.
#
# What to make of this analysis? In the subsequent sections, I attempt to replicate the findings of this article, and in so doing, highlight the perils of reporting statistical findings without adhering to scientific norms.

# %% [markdown]
# # Start your kernels...

# %% [markdown]
# In the sections below, I provide all the code I used to scrape data from the websites Hickey mentioned as sources as well as some others I use to extend his analysis. The goal here is to attempt to replicate Hickey's analyses using the same data and same methods he described. I want to emphasize three points ahead of time:
#
# 1. **What are the data?** Through this process of obtaining the data, it becomes clear that the analyst quickly has to make choices about the types of data to be obtained. Does the data come from Table X or Table Y? They *should* be the same, but there are things missing in one that aren't missing in the other. These decisions are not documented in the article nor are these data made available, both of which makes it hard to determine what exactly is being measured.
#
# 2. **What are the constructs?** The article also creates variables such as "return on investment" and "gross profits" from other variables in the data. The article doesn't actually say how these variables are constructed or where they come from, so I could be wrong but the data and tradition definitions of these variables present obvious candidates involving different relationships between the same two variables Budget (Expenses) and Income (Revenue). In creating a new variable that combines two other variables, the behavior of this new variable is instrinsically related to the other variables. This can become problematic very quickly, as we will see in the next step.
#
# 3. **What are the models?** The article then performs analyses on these new and old variables using methods that assume they should be independent. As the previous bullet emphasizes, "return on investment" and "gross profits" are financial performance outcomes that already capture a relationship between Budget and Income. The model *could* measure these outcomes as a function of the Bechdel score alone. The model could *also* estimate basic Income as a function of Bechdel plus throw in Budget as a control. The model might still also could try to estimate the combined financial performance as a function of Bechdel controlling for Budget again, *even though is already in the outcome.* The write-up makes it seem like the last model is the one used, which is problematic.

# %% [markdown]
# # 1. What are the data?

# %%
import pandas as pd
import json,urllib,urllib2,string
from collections import Counter
from matplotlib.collections import LineCollection
import statsmodels.api as sm
import statsmodels.formula.api as smf
from bs4 import BeautifulSoup
import seaborn as sb

# %%
def sig_tester(num):
    if num<0.05:
        return 'is significant'
    else:
        return 'is NOT significant'

# %% [markdown]
# * Bucket into 0 vs 3, which changes are most important
# * Movie theaters
# * Control for time released
# * Look for just first 5 weeks

# %% [markdown]
# ### Revenue data from The-Numbers.com

# %% [markdown]
# Revenue data taken from scraping http://www.the-numbers.com/movies/#tab=letter

# %% [raw]
# revenue_df_list = list()
#
# for character in string.printable[1:36]:
#     soup = BeautifulSoup(urllib2.urlopen('http://www.the-numbers.com/movies/letter/{0}'.format(character)).read())
#     archive = pd.read_html(soup.findAll('table')[0].encode('latin1'),header=0,flavor='bs4',infer_types=False)[0]
#     archive.columns = ['Released','Movie','Genre','Budget','Revenue','Trailer']
#     archive['Released'] = pd.to_datetime(archive['Released'],format=u"%b\xa0%d,\xa0%Y",coerce=True)
#     archive = archive.replace([u'\xa0',u'nan'],[np.nan,np.nan])
#     archive['Budget'] = archive['Budget'].dropna().str.replace('$','').apply(lambda x:int(x.replace(',','')))
#     archive['Revenue'] = archive['Revenue'].dropna().str.replace('$','').apply(lambda x:int(x.replace(',','')))
#     archive['Year'] = archive['Released'].apply(lambda x:x.year)
#     archive.dropna(subset=['Movie'],inplace=True)
#     revenue_df_list.append(archive)
#
# numbers_df = pd.concat(revenue_df_list)
# numbers_df.reset_index(inplace=True,drop=True)
# numbers_df.to_csv('revenue.csv',encoding='utf8')
# numbers_df.tail()

# %%
numbers_df = pd.read_csv('revenue.csv',encoding='utf8',index_col=0)
numbers_df['Released'] = pd.to_datetime(numbers_df['Released'],unit='D')
numbers_df.tail()
# Out:
#         Released       Movie              Genre    Budget  Revenue Trailer  \
# 19967 1979-12-14   Zulu Dawn                NaN       NaN        0     NaN
# 19968 2003-02-07    Zus & Zo                NaN       NaN    49468     NaN
# 19969 2007-04-06   Zwartboek  Thriller/Suspense  22000000  4398532     NaN
# 19970 2014-02-28  Zwei Leben              Drama       NaN    39673     NaN
# 19971 2006-02-24  Zyzzyx Rd.  Thriller/Suspense       NaN       20     NaN
#
#        Year
# 19967  1979
# 19968  2003
# 19969  2007
# 19970  2014
# 19971  2006
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Inflation data from BLS

# %% [markdown]
# Here I tried to write some code to get historical CPI data from the [BLS API](http://www.bls.gov/developers/home.htm), but I couldn't get it to work. Instead, I downloaded the January monthly data for Series ID `CUUR0000SA0` which is the "CPI - All Urban Consumers" and saved it as a CSV.

# %%
cpi = pd.read_csv('cpi.csv',index_col='Year')
inflator = dict(cpi.ix[2014,'Annual']/cpi['Annual'])

# %% [markdown]
# ### Bechdel Test data from BechdelTest.com's API

# %% [markdown]
# Documentation here: http://bechdeltest.com/api/v1/doc#getMovieByImdbId
#
# First, download a list of all movie IDs using hte `getAllMovieIds` method. Inspect the first 5. Create a list of IMDB ids out of this list of dictionaries to pass to the API.

# %%
movie_ids = json.loads(urllib2.urlopen('http://bechdeltest.com/api/v1/getAllMovieIds').read())
imdb_ids = [movie[u'imdbid'] for movie in movie_ids]
print u"There are {0} movies in the Bechdel test corpus".format(len(imdb_ids))
# Out:
# There are 5059 movies in the Bechdel test corpus

# %% [markdown]
# Pull an example `getMovieByImdbId` from the API.

# %%
json.loads(urllib2.urlopen('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=0000091').read())
# Out:
# {u'date': u'2013-12-25 14:31:21',
#  u'dubious': u'0',
#  u'id': u'4982',
#  u'imdbid': u'0000091',
#  u'rating': u'0',
#  u'submitterid': u'9025',
#  u'title': u'House of the Devil, The',
#  u'visible': u'1',
#  u'year': u'1896'}

# %% [markdown]
# Pull all of the data we can down. This may take a while. We don't want to have to repeat that crawl again, so let's write the data to disk as `bechdel.json`

# %% [raw]
# ratings = dict()
# exceptions = list()
# for num,imdb_id in enumerate(imdb_ids):
#     try:
#         if num in range(0,len(imdb_ids),int(round(len(imdb_ids)/10,0))):
#             print imdb_id
#         ratings[imdb_id] = json.loads(urllib2.urlopen('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid={0}'.format(imdb_id)).read())
#     except:
#         exceptions.append(imdb_id)
#         pass
#
# with open('bechdel.json', 'wb') as f:
#   json.dump(ratings.values(), f)

# %% [markdown]
# Read the data back from disk and convert to `ratings_df`.

# %%
ratings_df = pd.read_json('bechdel.json')
ratings_df['imdbid'] = ratings_df['imdbid'].dropna().apply(int)
ratings_df = ratings_df.set_index('imdbid')

# %%
ratings_df['new_rating'] = pd.Series(index=ratings_df.index)
ratings_df.loc[((ratings_df['dubious'] == u'0') & (ratings_df['rating'] == 0)),'new_rating'] = 0.0
ratings_df.loc[((ratings_df['dubious'] == u'1') & (ratings_df['rating'] == 1)),'new_rating'] = 0.5
ratings_df.loc[((ratings_df['dubious'] == u'0') & (ratings_df['rating'] == 1)),'new_rating'] = 1.0
ratings_df.loc[((ratings_df['dubious'] == u'1') & (ratings_df['rating'] == 2)),'new_rating'] = 1.5
ratings_df.loc[((ratings_df['dubious'] == u'0') & (ratings_df['rating'] == 2)),'new_rating'] = 2.0
ratings_df.loc[((ratings_df['dubious'] == u'1') & (ratings_df['rating'] == 3)),'new_rating'] = 2.5
ratings_df.loc[((ratings_df['dubious'] == u'0') & (ratings_df['rating'] == 3)),'new_rating'] = 3.0

# %%
ratings_df.dropna(subset=['title'],inplace=True)
ratings_df2 = ratings_df[['rating','new_rating','title']]
ratings_df2.head()
# Out:
#          rating  new_rating               title
# imdbid
# 435528        2         2.0             Whisper
# 1456472       1         1.0      We Have a Pope
# 435680        3         3.0          Kidulthood
# 460721        3         3.0   Big Bad Swim, The
# 1571222       3         2.5  A Dangerous Method
#
# [5 rows x 3 columns]

# %% [markdown]
# They field we want is `rating` which is defined as:
#
#     "The actual score. Number from 0 to 3.
#     0.0 means no two women,
#     0.5 means two women (dubious),
#     1.0 means no talking,
#     1.5 means two women talking (dubious),
#     2.0 means talking about a man,
#     2.5 means talking about something other than a man (dubious),
#     3.0 means it passes the test."

# %% [markdown]
# ### Additional data from OMDBAPI

# %% [markdown]
# Pull an example from http://www.omdbapi.com/.

# %%
json.loads(urllib2.urlopen('http://www.omdbapi.com/?i=tt0000091').read())
# Out:
# {u'Actors': u"Jeanne d'Alcy, Georges M\xe9li\xe8s",
#  u'Awards': u'N/A',
#  u'Country': u'France',
#  u'Director': u'Georges M\xe9li\xe8s',
#  u'Genre': u'Short, Horror',
#  u'Language': u'N/A',
#  u'Metascore': u'N/A',
#  u'Plot': u'A bat flies into an ancient castle and transforms itself into Mephistopheles himself. Producing a cauldron, Mephistopheles conjures up a young girl and various supernatural creatures, one ...',
#  u'Poster': u'N/A',
#  u'Rated': u'N/A',
#  u'Released': u'N/A',
#  u'Response': u'True',
#  u'Runtime': u'3 min',
#  u'Title': u'The House of the Devil',
#  u'Type': u'movie',
#  u'Writer': u'Georges M\xe9li\xe8s',
#  u'Year': u'1896',
#  u'imdbID': u'tt0000091',
#  u'imdbRating': u'6.8',
#  u'imdbVotes': u'768'}

# %% [markdown]
# Crawl the data. This will take a while. Write the data to disk when you're done as `imdb_data.json`.

# %% [raw]
# imdb_data = dict()
# exceptions = list()
# for num,imdb_id in enumerate(imdb_ids):
#     try:
#         if num in range(0,len(imdb_ids),int(round(len(imdb_ids)/10,0))):
#             print imdb_id
#         imdb_data[imdb_id] = json.loads(urllib2.urlopen('http://www.omdbapi.com/?i=tt{0}'.format(imdb_id)).read())
#     except:
#         exceptions.append(imdb_id)
#         pass
#
# with open('imdb_data.json', 'wb') as f:
#   json.dump(imdb_data.values(), f)

# %% [markdown]
# Read the data back from disk and convert to `imdb_df`. Print out an example row, but transpose it because there are a lot of columns.

# %%
imdb_df = pd.read_json('imdb_data.json')
imdb_df['Released'] = pd.to_datetime(imdb_df['Released'], format="%d %b %Y", coerce=True)
imdb_df['imdbID'] = imdb_df['imdbID'].str.slice(start=2)
imdb_df.tail(1).T
# Out:
#                                                          5022
# Actors      Anne Dorval, Xavier Dolan, François Arnaud, Su...
# Awards                              27 wins & 13 nominations.
# Country                                                Canada
# Director                                         Xavier Dolan
# Error                                                     NaN
# Genre                                                   Drama
# Language                                               French
# Metascore                                                  83
# Plot        A semi-autobiographical story about Dolan as a...
# Poster      http://ia.media-imdb.com/images/M/MV5BMTM2MDg0...
# Rated                                               Not Rated
# Released                                  2009-07-15 00:00:00
# Response                                                 True
# Runtime                                                96 min
# ...

# %% [markdown]
# More cleanup happens below.

# %%
# Remove the " min" at the end of Runtime entries so we can convert to ints
imdb_df['Runtime'] = imdb_df['Runtime'].str.slice(stop=-4).replace('',np.nan)

# Some errant runtimes have "h" in them. Commented-out code below identifies them.
#s = imdb_df['Runtime'].dropna()
#s[s.str.contains('h')]

# Manually recode these h-containing Runtimes to minutes
imdb_df.ix[946,'Runtime'] = '169'
imdb_df.ix[1192,'Runtime'] = '96'
imdb_df.ix[1652,'Runtime'] = '80'
imdb_df.ix[2337,'Runtime'] = '87'
imdb_df.ix[3335,'Runtime'] = '62'

# Convert Release into years
imdb_df['Year'] = imdb_df['Released'].apply(lambda x:x.year)

# Extract month and week of the year
imdb_df['Month'] = imdb_df['Released'].apply(lambda x:x.month)
imdb_df['Week'] = imdb_df['Released'].apply(lambda x:x.week)

# Convert the series to float
imdb_df['Runtime'] = imdb_df['Runtime'].apply(float)

# Take the imdbVotes formatted as string containing "N/A" and comma-delimited thousands, convert to float
imdb_df['imdbVotes'] = imdb_df['imdbVotes'].dropna().replace('N/A',np.nan).dropna().apply(lambda x:float(x.replace(',','')))

# Take the Metascore formatted as string containing "N/A", convert to float
imdb_df['Metascore'] = imdb_df['Metascore'].dropna().replace('N/A',np.nan).dropna().apply(float)

# Take the imdbRating formatted as string containing "N/A", convert to float
imdb_df['imdbRating'] = imdb_df['imdbRating'].dropna().replace('N/A',np.nan).dropna().apply(float)

# Convert imdb_ID to int, set it as the index
imdb_df['imdbID'] = imdb_df['imdbID'].dropna().apply(int)
imdb_df = imdb_df.set_index('imdbID')

# %% [markdown]
# ### Join datasets together

# %%
df = imdb_df.join(ratings_df2,how='inner').reset_index()
df = pd.merge(df,numbers_df,left_on=['Title','Year'],right_on=['Movie','Year'])
df['Year'] = df['Released_x'].apply(lambda x:x.year)
df['Adj_Revenue'] = df.apply(lambda x:x['Revenue']*inflator[x['Year']],axis=1)
df['Adj_Budget'] = df.apply(lambda x:x['Budget']*inflator[x['Year']],axis=1)

df.tail(2).T
# Out:
#                                                           2625  \
# index                                                  3322420
# Actors       Kangana Ranaut, Rajkummar Rao, Lisa Haydon, Mi...
# Awards                                                     N/A
# Country                                                  India
# Director                                            Vikas Bahl
# Error                                                      NaN
# Genre_x                                          Comedy, Drama
# Language                                                 Hindi
# Metascore                                                  NaN
# Plot         A Delhi girl from a traditional family sets ou...
# Poster       http://ia.media-imdb.com/images/M/MV5BMTQ1ODUx...
# Rated                                                      N/A
# Released_x                                 2014-03-07 00:00:00
# Response                                                  True
# ...

# %% [markdown]
# # 2 . What are the constructs?

# %% [markdown]
# Now that we have data in hand about movies, their financial performance, and their performance on the Bechdel test from the data sources that Hickey descibed in the article, we can attempt to replicate the specific variables used. Because the article does not make clear which data or definitions were used for making these constructs, we're left to infer what exactly what Hickey did.
#
# The article claims to use two specific outcomes: **return on investment** and **gross profits** which are different ways of accounting for the relationship between income and costs. I don't claim to be an accounting of business expert, but "gross profit" is traditionally defined as "income minus costs" ($P = I - C$) while "return on investment" (RoI) is traditionally defined as profits divided by assets ($ROI = P/A$). Thus we need at least three variables: income, costs, and assets.
#
# However, only two of these are available in the movie financial data we obtained from [The-Numbers.com](http://www.the-numbers.com): income and costs. We can calculate profits easily, but it's unclear what a movie's assets are here unless we use costs again. Again, Hickey may have done something different for make this variable, but we don't know so we can't replicate.

# %%
df['Profit'] = df['Adj_Revenue'] - df['Adj_Budget']
df['ROI'] = df['Profit']/df['Adj_Budget']

# %% [markdown]
# # 3. What are the models?

# %% [markdown]
# ### Bechdel Test over time

# %% [markdown]
# Plot the change in the average Bechdel score over time. Scale the size of the line by the (logged) number of movies released that year.

# %%
# Do some fancy re-indexing and groupby operations to get 
# average scores and number of movies between 1912 and 2013
avg_bechdel = df.set_index('Released_x').groupby(lambda x:x.year)['new_rating'].agg(np.mean)
num_movies = df.set_index('Released_x').groupby(lambda x:x.year)['new_rating'].agg(lambda x:np.power(len(x)+1,1/2.5))

# Changing line widths from: http://stackoverflow.com/questions/19862011/matplotlib-change-linewidth-on-line-segments-using-list
coords = sorted(dict(avg_bechdel).items(),key=lambda x:x[0])
lines = [(start, end) for start, end in zip(coords[:-1], coords[1:])]
lines = LineCollection(lines, linewidths=dict(num_movies).values())

# Plot the figure
fig, ax = plt.subplots()
ax.add_collection(lines)
plt.autoscale()
plt.xlim((1912,2020))
plt.xlabel('Time',fontsize=18)
plt.ylabel('Avg. Bechdel score',fontsize=18)

# %%
df_rating_ct = pd.crosstab(df['Year'],df['rating'])

# Bakes in a lot here and is bad Pythonic form -- but I'm lazy
# http://stackoverflow.com/questions/17764619/pandas-dataframe-group-year-index-by-decade
# http://stackoverflow.com/questions/21247203/how-to-make-a-pandas-crosstab-with-percentages
# http://stackoverflow.com/questions/9938130/plotting-stacked-barplots-on-a-panda-data-frame

df_rating_ct.groupby((df_rating_ct.index//10)*10).sum().apply(lambda x: x/x.sum(),axis=1).ix[1930:].plot(kind='bar',stacked=True)

# Fix up the plot
plt.ylabel('Percentage of movies',fontsize=18)
plt.yticks(arange(0,1.1,.10),arange(0,110,10),fontsize=15)
plt.xlabel('Decade',fontsize=18)
plt.xticks(rotation=0,fontsize=15)
plt.legend(loc='center',bbox_to_anchor=(1.1,.5),title='Bechdel dims.')

# %% [markdown]
# We can also estimate a statistical model to forecast future changes in the average Bechdel score over time. We observe a general upward trend and can estimate a simple model that this same pattern will continue forward into time average movie passes the test.

# %%
avg_bechdel = df.set_index('Released_x').groupby(lambda x:x.year)['new_rating'].agg(np.mean)
avg_bechdel.index.name = 'date'
avg_bechdel.name = 'bechdel'
avg_bechdel = avg_bechdel.reset_index()

l_model = smf.ols(formula='bechdel ~ date', data=avg_bechdel).fit()
print l_model.summary()

# Create a DataFrame "X" that we can extrapolate into
X = pd.DataFrame({"date": np.linspace(start=1912.,stop=2100.,num=100)})

# Plot the observed data
plt.plot(avg_bechdel['date'],avg_bechdel['bechdel'],c='b',label='Observed')

# Plot the predictions from the model
plt.plot(X,l_model.predict(X),c='r',label='Linear model',lw=4)
plt.legend(loc='lower right')
plt.ylim((0,3))
plt.xlim((1912,2100))
plt.xlabel('Year')
plt.ylabel('Avg. Bechdel Test')

plt.xlabel('Year',fontsize=18)
plt.ylabel('Avg. Bechdel Test',fontsize=18)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                bechdel   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     17.77
# Date:                Sat, 05 Apr 2014   Prob (F-statistic):           6.32e-05
# Time:                        01:27:14   Log-Likelihood:                -66.018
# No. Observations:                  85   AIC:                             136.0
# Df Residuals:                      83   BIC:                             140.9
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -16.7433      4.418     -3.789      0.000       -25.531    -7.955
# date           0.0094      0.002      4.215      0.000         0.005     0.014
# ...

# %% [markdown]
# Re-arrange the $y=Bx+I$ equation to solve for `y=30`: $x=(y-I)/B$
#
# Then convert the float into a proper date and return the day of the week as well (Mondays are 0).

# %%
year_est = (3 - l_model.params['Intercept'])/l_model.params['date']
year_int = int(year_est)
d = datetime.timedelta(days=(year_est - year_int)*365.25)
day_one = datetime.datetime(year_int,1,1)
date = d + day_one
print date, date.weekday()
# Out:
# 2089-12-29 03:55:29.662504 3

# %% [markdown]
# Extrapolating this linear model forward in time, on **Thursday, December 29, 2089**, the ***average*** movie will finally pass the Bechdel test. Just 75 years to go until that when magical Friday release when even the average summer blockbuster will have minimally-developed female characters! Hooray!
#
# But there could also be other things going on in the model. Maybe the rate at which movies passing the Bechdel test is accelerating or decelerating instead of changing constantly. We estimate a model with a quadratic term on time below. This model says we've apparently passed "Peak Bechdel" back in the 1990s and we're regressing towards a mysogynist cultural dystopia in the future.
#
# But we shouldn't put too much stock in such simple models -- espcially when they make such divergent predictions about the 2090s.

# %%
q_model = smf.ols(formula='bechdel ~ date + I(date**2)', data=avg_bechdel).fit()

# Create a DataFrame "X" that we can extrapolate into
X = pd.DataFrame({"date": np.linspace(start=1912.,stop=2112.,num=201)})

# Plot the observed data
plt.plot(avg_bechdel['date'],avg_bechdel['bechdel'],c='b',label='Observed')

# Plot the predictions from the model
plt.plot(X,q_model.predict(X),c='r',label='Quadratic model',lw=4)
plt.legend(loc='upper right')
plt.ylim((0,3))
plt.xlim((1912,2112))
plt.xlabel('Year',fontsize=18)
plt.ylabel('Avg. Bechdel Test',fontsize=18)

# %% [markdown]
# ### Budgets differ

# %% [markdown]
# As I discussed above, the claim that budgets for Bechdel-passing movies is relatively uncontroversial and given the description of the data in the article, should be easy to reproduce. Visualizing the distribution of the data, there are no strong differences that jump out but if you squint hard enough, you can make out a negative trend: movies passing the Bechdel test have lower budgets.
#
# You'll notice each cloud of points around 0, 1, 2, and 3. These are simply "jittered" by adding a bit of normally-distributed errors to the plots (but not the underlying data we're estimating) to show the frequency of datapoints without them all sitting on top of each other.

# %%
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df['Adj_Budget']

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.ylabel('Budgets (2014 $)',fontsize=18)
plt.xlabel('Bechdel dimensions',fontsize=18)
plt.xticks(arange(0,4))
plt.yscale('log')
plt.grid(False,which='minor')
#plt.ylim((2e0,1e10))

# %%
df['Adj_Budget'].groupby(df['rating']).agg(np.median).plot(kind='barh')
plt.yticks(fontsize=18)
plt.xticks(arange(0e7,7e7,1e7),arange(0,70,10),fontsize=15)
plt.yticks(arange(.6,4.6,1),["Fewer than two women",
                             "Women don't talk to each other",
                             'Women only talk about men',
                             'Passes Bechdel Test'
                             ])
plt.xlabel('Budget (2014 $millions)',fontsize=18)
plt.title('Median Budget for Films Since 1990',fontsize=24)
plt.ylabel('')

# %% [markdown]
# > In order to get a consistent look at budget data, we’re going to focus on films released from 1990 to 2013, since the data has significantly more depth since then... We rely on median, as opposed to average, budgets to minimize the effect of outliers, or in this case, huge blockbusters whose budgets are orders of magnitude larger than the typical movie’s budget. We ran a statistical test analyzing the inflation-adjusted median budgets of films, and found that films passing the Bechdet Test had a median budget that was 16 percent lower than the median budget of all films in the set.
#
# With skewed data choosing medians doesn't always help, so I'll log-transform the data instead to restore normality. We can quantitatively test this hypothesis by regressing budget against these categories. Indeed, the `-0.2504` estimate for `C(rating)[T.3.0]` confirms the finding that movies passing all 3 Bechdel dimensions have significantly lower budgets than movies that pass none of the Bechdel dimensions. The model predicts that movies that fail every Bechdel dimension have budgets of \$13.6 million on average while movies that pass every Bechdel dimension have budgets of \$10.6 million on average --- a $3.0 million dollar or 22% difference.
#
# But this simple model does a poor job explaining the distribution of data -- it explains 2.3% of the variance. Furthermore, we can also chalk this difference up to a number of other explanations as well: the Bechdel test may be standing in for differences in other variables such as genre, year, time of year, and composition of the cast and crew, among many possibilities. We'll explore some of these later.

# %%
bd_m = smf.ols(formula='log(Adj_Budget+1) ~ C(rating)', data=df).fit()
print bd_m.summary()

print "\n\nMovies passing every Bechdel dimension have budgets of ${:,} on average.".format(round(np.exp(bd_m.params['Intercept']+bd_m.params['C(rating)[T.3.0]']-1),2))
print "Movies failing every Bechdel dimension have budgets of ${:,} on average.".format(round(np.exp(bd_m.params['Intercept']-1),2))
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     log(Adj_Budget + 1)   R-squared:                       0.023
# Model:                             OLS   Adj. R-squared:                  0.021
# Method:                  Least Squares   F-statistic:                     12.35
# Date:                 Sat, 05 Apr 2014   Prob (F-statistic):           5.52e-08
# Time:                         02:35:38   Log-Likelihood:                -2632.4
# No. Observations:                 1583   AIC:                             5273.
# Df Residuals:                     1579   BIC:                             5294.
# Df Model:                            3
# ...
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept           17.4318      0.115    151.286      0.000        17.206    17.658
# ...

# %% [markdown]
# ### Earnings differ

# %% [markdown]
# > ...we ran a regression to find out if passing the Bechdel test corresponded to lower return on investment. Controlling for the movie’s budget, which has a negative and significant relationship to a film’s return on investment,7 passing the Bechdel test had no effect on the film’s return on investment.

# %%
# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df['ROI']

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4),fontsize=15)
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('ROI',fontsize=18)
plt.yscale('symlog')
plt.grid(False,which='minor')

# Estimate the model
ed_m1 = smf.ols(formula='ROI ~ C(rating)  + log(Budget+1)', data=df).fit()
print ed_m1.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    ROI   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     70.34
# Date:                Sat, 05 Apr 2014   Prob (F-statistic):           7.22e-55
# Time:                        03:42:24   Log-Likelihood:                -6190.1
# No. Observations:                1583   AIC:                         1.239e+04
# Df Residuals:                    1578   BIC:                         1.242e+04
# Df Model:                           4
# ...
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept           62.1188      3.840     16.177      0.000        54.587    69.651
# ...

# %%
# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df['Profit']

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4),fontsize=15)
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('Profit (2014 $ millions)',fontsize=18)
plt.yticks(arange(-.5e9,2e9,.5e9),arange(-500,2000,500),fontsize=15)
plt.xticks(fontsize=15)
plt.grid(False,which='minor')

# Estimate the model
ed_m2 = smf.ols(formula='Profit ~ C(rating)  + log(Budget+1)', data=df).fit()
print ed_m2.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.622
# Date:                Sat, 05 Apr 2014   Prob (F-statistic):            0.00103
# Time:                        03:41:04   Log-Likelihood:                -31704.
# No. Observations:                1583   AIC:                         6.342e+04
# Df Residuals:                    1578   BIC:                         6.344e+04
# Df Model:                           4
# ...
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         1.957e+08   3.84e+07      5.099      0.000       1.2e+08  2.71e+08
# ...

# %% [markdown]
# ## Relationship between Bechdel score and revenue

# %% [markdown]
# This is the "raw" distribution of the relationship between Bechdel scores (x-axis) and annual revenue (y-axis). Just look at it speaking for itself! Verily, it leaps off the page!
#
# We want to model this relationship, but first we want to explain away other potentially confounding sources of variation in the relationship coming from differences in genre, critics' scores, fans' scores, production budgets, year of release, month of release, length of the movie, and opening theaters, among others.

# %%
# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df['Adj_Revenue']+1

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4))
plt.yscale('log')
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('Adj. Revenue (2014 $)',fontsize=18)
plt.ylim((2e0,1e10))
plt.grid(False,which='minor')
#plt.legend(loc='right',bbox_to_anchor=(1.275,.5))

# %% [markdown]
# There's no clear trend here, lots of clouds of points with their bunches pretty much all at the same level, just below $10^8$. Let's run the numbers to see if there's actually a trend.
#
# The first model we estimate is replicating the 538 analysis whether there's a relationship between revenue and Bechdel score, controlling for budget. We fit this model properly using `rating` as a categorical variable and logging the highly-skewed `Revenue` and `Budget` variables.

# %%
m1 = smf.ols(formula='log(Adj_Revenue+1) ~ C(rating) + log(Adj_Budget+1)', data=df).fit()
print m1.summary()
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     log(Adj_Revenue + 1)   R-squared:                       0.244
# Model:                              OLS   Adj. R-squared:                  0.242
# Method:                   Least Squares   F-statistic:                     127.2
# Date:                  Sat, 05 Apr 2014   Prob (F-statistic):           3.12e-94
# Time:                          03:43:26   Log-Likelihood:                -3338.6
# No. Observations:                  1583   AIC:                             6687.
# Df Residuals:                      1578   BIC:                             6714.
# Df Model:                             4
# ...
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               1.8864      0.709      2.661      0.008         0.496     3.277
# ...

# %%
m1_b0 = np.exp(m1.params['Intercept'] + m1.params['log(Adj_Budget + 1)']*np.log(np.mean(df['Adj_Budget'])))
m1_b1 = np.exp(m1.params['Intercept'] + m1.params['C(rating)[T.1.0]'] + m1.params['log(Adj_Budget + 1)']*np.log(np.mean(df['Adj_Budget'])))
m1_b2 = np.exp(m1.params['Intercept'] + m1.params['C(rating)[T.2.0]'] + m1.params['log(Adj_Budget + 1)']*np.log(np.mean(df['Adj_Budget'])))
m1_b3 = np.exp(m1.params['Intercept'] + m1.params['C(rating)[T.3.0]'] + m1.params['log(Adj_Budget + 1)']*np.log(np.mean(df['Adj_Budget'])))

print "Movies with an average budget and passing no element of the Bechdel test will make ${:,} on average".format(round(m1_b0,-3))
print "Movies with an average budget and passing the first element of the Bechdel test will make ${:,} on average".format(round(m1_b1,-3))
print "Movies with an average budget and passing the second element of the Bechdel test will make ${:,} on average".format(round(m1_b2,-3))
print "Movies with an average budget but passing all elements of the Bechdel test will make ${:,} on average".format(round(m1_b3,-3))
# Out:
# Movies with an average budget and passing no element of the Bechdel test will make $46,877,000.0 on average
# Movies with an average budget and passing the first element of the Bechdel test will make $61,660,000.0 on average
# Movies with an average budget and passing the second element of the Bechdel test will make $86,237,000.0 on average
# Movies with an average budget but passing all elements of the Bechdel test will make $73,390,000.0 on average

# %% [markdown]
# Next we estimate a "bad" model using `rating` as a continuous variable so that we can visualize the model on top of the data itself.

# %%
m1_bad_res = smf.ols(formula='log(Adj_Revenue+1) ~ rating + log(Adj_Budget+1)', data=df[df['Adj_Revenue']>0]).fit()
print m1_bad_res.summary()
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     log(Adj_Revenue + 1)   R-squared:                       0.369
# Model:                              OLS   Adj. R-squared:                  0.368
# Method:                   Least Squares   F-statistic:                     456.9
# Date:                  Sat, 05 Apr 2014   Prob (F-statistic):          4.85e-157
# Time:                          03:45:46   Log-Likelihood:                -2594.7
# No. Observations:                  1569   AIC:                             5195.
# Df Residuals:                      1566   BIC:                             5212.
# Df Model:                             2
# ...
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               4.3251      0.454      9.535      0.000         3.435     5.215
# ...

# %%
# Estimate model without the Bechdel test IV and containing only the IVs to get residulals
m1_bad_res = smf.ols(formula='log(Adj_Revenue+1) ~ log(Adj_Budget+1)', data=df[df['Adj_Revenue']>0]).fit()

# Put these residual estimates in a temporary DataFrame
df_temp = df
df_temp['residuals'] = m1_bad_res.resid

# Estimate a bad model with a continuous Bechdel rating against the residuals
m1_bad = smf.ols(formula='residuals ~ rating', data=df_temp).fit()
m1_bad_x = pd.DataFrame({'rating':np.linspace(min(df['rating']),max(df['rating']),100)})

# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df_temp['residuals']

plt.plot(m1_bad_x['rating'],m1_bad.predict(m1_bad_x),c='r',lw=2,label='Model')

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4))
#plt.yscale('log')
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('Residual Adj. Revenue',fontsize=18)
plt.ylim((-10,10))
plt.legend(loc='lower left')
print "Every additional Bechdel 'point' adds {0} to the revenue and {1}".format(round(m1_bad.params['rating'],3),sig_tester(m1_bad.pvalues['rating']))
# Out:
# Every additional Bechdel 'point' adds 0.056 to the revenue and is NOT significant

# %% [markdown]
# ## Relationship between Bechdel score and Metascore

# %%
m2 = smf.ols(formula='Metascore ~ C(rating) + log(Adj_Budget+1)', data=df).fit()
print m2.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Metascore   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     7.607
# Date:                Sat, 05 Apr 2014   Prob (F-statistic):           4.63e-06
# Time:                        03:46:36   Log-Likelihood:                -5833.5
# No. Observations:                1373   AIC:                         1.168e+04
# Df Residuals:                    1368   BIC:                         1.170e+04
# Df Model:                           4
# ...
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept              92.6345      6.552     14.138      0.000        79.782   105.488
# ...

# %% [markdown]
# Again, estimate a bad model with continuous Bechdel ratings to plot over the data.

# %%
# Estimate model without the Bechdel test IV and containing only the IVs to get residulals
m2_bad_res = smf.ols(formula='Metascore ~ log(Adj_Budget+1)', data=df).fit()

# Put these residual estimates in a temporary DataFrame
df_temp = df
df_temp['residuals'] = m2_bad_res.resid

# Estimate a bad model with a continuous Bechdel rating against the residuals
m2_bad = smf.ols(formula='residuals ~ rating', data=df_temp).fit()
m2_bad_x = pd.DataFrame({'rating':np.linspace(min(df['rating']),max(df['rating']),100)})

# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df_temp['residuals']

plt.plot(m2_bad_x['rating'],m2_bad.predict(m2_bad_x),c='r',lw=2,label='Model')

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4))
#plt.yscale('log')
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('Residual Metascore',fontsize=18)
plt.legend(loc='lower left')
print "Every additional Bechdel 'point' adds {0} to the Metascore and {1}".format(round(m2_bad.params['rating'],2),sig_tester(m2_bad.pvalues['rating']))
# Out:
# Every additional Bechdel 'point' adds -0.68 to the Metascore and is NOT significant

# %% [markdown]
# ## Relationship between IMDB rating and Bechdel score

# %%
m3 = smf.ols(formula='imdbRating ~ C(rating) + log(Adj_Budget+1) + log(imdbVotes+1)', data=df).fit()
print m3.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             imdbRating   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     134.9
# Date:                Sat, 05 Apr 2014   Prob (F-statistic):          3.05e-119
# Time:                        03:47:56   Log-Likelihood:                -1927.4
# No. Observations:                1582   AIC:                             3867.
# Df Residuals:                    1576   BIC:                             3899.
# Df Model:                           5
# ...
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               5.1252      0.308     16.624      0.000         4.520     5.730
# ...

# %%
# Estimate model without the Bechdel test IV and containing only the IVs to get residulals
m3_bad_res = smf.ols(formula='imdbRating ~ log(Adj_Budget+1) + log(imdbVotes+1)', data=df).fit()

# Put these residual estimates in a temporary DataFrame
df_temp = df
df_temp['residuals'] = m3_bad_res.resid

# Estimate a bad model with a continuous Bechdel rating against the residuals
m3_bad = smf.ols(formula='residuals ~ rating', data=df_temp).fit()
m3_bad_x = pd.DataFrame({'rating':np.linspace(min(df['rating']),max(df['rating']),100)})

# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df_temp['residuals']

plt.plot(m3_bad_x['rating'],m3_bad.predict(m3_bad_x),c='r',lw=2,label='Model')

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4))
#plt.yscale('log')
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('Residual IMDB rating',fontsize=18)
plt.legend(loc='lower left')

print "Every additional Bechdel 'point' adds {0} to the rating and {1}".format(round(m3_bad.params['rating'],2),sig_tester(m3_bad.pvalues['rating']))
# Out:
# Every additional Bechdel 'point' adds -0.07 to the rating and is significant

# %% [markdown]
# ## Full model

# %%
m4 = smf.ols(formula='log(Adj_Revenue+1) ~ C(rating) + log(Adj_Budget+1) + Metascore + imdbRating + log(imdbVotes+1) + Runtime + C(Genre_y) + C(Year) + C(Week)', data=df).fit()
print m4.summary()
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     log(Adj_Revenue + 1)   R-squared:                       0.996
# Model:                              OLS   Adj. R-squared:                  0.996
# Method:                   Least Squares   F-statistic:                     2926.
# Date:                  Sat, 05 Apr 2014   Prob (F-statistic):               0.00
# Time:                          03:48:41   Log-Likelihood:                -2000.3
# No. Observations:                  1354   AIC:                             4237.
# Df Residuals:                      1236   BIC:                             4852.
# Df Model:                           118
# ...
#                                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------------
# Intercept                             1.6527      0.703      2.350      0.019         0.273     3.033
# ...

# %%
# Estimate model without the Bechdel test IV and containing only the IVs to get residulals
m4_bad_res = smf.ols(formula='log(Adj_Revenue+1) ~ log(Adj_Budget+1) + Metascore + imdbRating + log(imdbVotes+1) + Runtime + C(Genre_y) + C(Year) + C(Week)', data=df).fit()

# Put these residual estimates in a temporary DataFrame
df_temp = df
df_temp['residuals'] = m4_bad_res.resid

# Estimate a bad model with a continuous Bechdel rating against the residuals
m4_bad = smf.ols(formula='residuals ~ rating', data=df_temp).fit()
m4_bad_x = pd.DataFrame({'rating':np.linspace(min(df['rating']),max(df['rating']),100)})

# Add a jitter so the points aren't overlapping
x = df['rating'].apply(lambda x:float(x)+np.random.normal(0, 0.05))
y = df_temp['residuals']

plt.plot(m4_bad_x['rating'],m4_bad.predict(m4_bad_x),c='r',lw=2,label='Model')

# Plot with an alpha so the overlaps reveal something about relative density
plt.scatter(x,y,alpha=.2,label='Data',c='g')
plt.xticks(arange(0,4))
#plt.yscale('log')
plt.autoscale()
plt.xlabel('Bechdel score',fontsize=18)
plt.ylabel('Residual Adj. Revenue',fontsize=18)
plt.legend(loc='lower left')
print "Every additional Bechdel 'point' adds {0} to the revenue and {1}".format(round(m4_bad.params['rating'],2),sig_tester(m4_bad.pvalues['rating']))
# Out:
# Every additional Bechdel 'point' adds 0.14 to the revenue and is significant

# %% [markdown]
# ## Relationship between Bechdel and Genre

# %%
sb.boxplot(df['rating'],groupby=df['Genre_y'])
plt.xticks(rotation=45)

plt.xlabel('Genre',fontsize=18)
plt.ylabel('Bechdel Test',fontsize=18)

# %% [markdown]
# ## Relationship between IMDB and Metascore

# %%
plt.scatter(df['Metascore'],df['imdbRating'],alpha=.25,s=np.power(df['Adj_Revenue'],1.0/4),c=df['new_rating']**2,cmap=plt.cm.Reds)
plt.xlim((0,100))
plt.ylim((0,10))
plt.xlabel('Metascore',fontsize=18)
plt.ylabel('IMDB Rating',fontsize=18)

# %%
plt.scatter(df['Adj_Budget']+1,df['Adj_Revenue']+1,alpha=.15,c=df['new_rating']**2,cmap=plt.cm.Reds)

plt.xscale('log')
plt.yscale('log')
plt.ylim((2e0,10e10))
plt.xlabel('Budget (2014 $)',fontsize=18)
plt.ylabel('Revenue (2014 $)',fontsize=18)
plt.grid(False,which='minor')

# %%
plt.scatter(df['imdbVotes']+1,df['imdbRating']+1,alpha=.15,c=df['new_rating']**2,cmap=plt.cm.Reds)

plt.xscale('log')
plt.ylim((0,10.9))
plt.xlim((0,9e6))

plt.xlabel('IMDB Votes',fontsize=18)
plt.ylabel('IMDB Rating',fontsize=18)
plt.grid(False,which='minor')

# %%
plt.scatter(df['imdbVotes']+1,df['Adj_Revenue']+1,alpha=.15,c=df['new_rating']**2,cmap=plt.cm.Reds)

plt.xscale('log')
plt.yscale('log')
plt.ylim((2e0,10e10))
plt.xlabel('IMDB Votes',fontsize=18)
plt.ylabel('Revenue (2014 $)',fontsize=18)
plt.grid(False,which='minor')
